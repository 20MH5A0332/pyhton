# %%
import pandas as pd,seaborn as sns,matplotlib.pyplot as plt,numpy as np

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic.isnull(
)
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic.isnull().any()
# Out:
# survived       False
# pclass         False
# sex            False
# age             True
# sibsp          False
# parch          False
# fare           False
# embarked        True
# class          False
# who            False
# adult_male     False
# deck            True
# embark_town     True
# alive          False
# alone          False
# dtype: bool

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanic.columns[titanic.isnull().any()]
# Out:
# Index(['age', 'embarked', 'deck', 'embark_town'], dtype='object')

# %%
list(titanic.columns[titanic.isnull().any()])
# Out:
# ['age', 'embarked', 'deck', 'embark_town']

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.dropna(how='any')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.dropna(how='any').shape
# Out:
# (182, 15)

# %%
titanic.dropna(how='all').shape
# Out:
# (891, 15)

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic['embark_town'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: embark_town, Length: 891, dtype: bool

# %%
titanic['embark_town'].isnull().sum()
# Out:
# 2

# %%
titanic[titanic['embark_town'].isnull()]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town alive  alone
# 61   woman       False    B         NaN   yes   True
# 829  woman       False    B         NaN   yes   True

# %%
titanic[~titanic['embark_town'].isnull()].shape
# Out:
# (889, 15)

# %%
titanic[~titanic['age'].isnull()].shape
# Out:
# (714, 15)

# %%
ser_embark_town =  titanic['embark_town'].isnull()
ser_age = titanic['age'].isnull()

# %%
titanic[(ser_embark_town)&(ser_age)].shape
# Out:
# (0, 15)

# %%
titanic[(ser_embark_town)|(ser_age)].shape
# Out:
# (179, 15)

# %%
titanic.dropna(how='any',axis=1)
# Out:
#      survived  pclass     sex  sibsp  parch     fare   class    who  \
# 0           0       3    male      1      0   7.2500   Third    man
# 1           1       1  female      1      0  71.2833   First  woman
# 2           1       3  female      0      0   7.9250   Third  woman
# 3           1       1  female      1      0  53.1000   First  woman
# 4           0       3    male      0      0   8.0500   Third    man
# ..        ...     ...     ...    ...    ...      ...     ...    ...
# 886         0       2    male      0      0  13.0000  Second    man
# 887         1       1  female      0      0  30.0000   First  woman
# 888         0       3  female      1      2  23.4500   Third  woman
# 889         1       1    male      0      0  30.0000   First    man
# 890         0       3    male      0      0   7.7500   Third    man
#
#      adult_male alive  alone
# 0          True    no  False
# 1         False   yes  False
# 2         False   yes   True
# 3         False   yes  False
# ...

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic['age'].median()
# Out:
# 28.0

# %%
titanic['age'].describe().round(1)
# Out:
# count    714.0
# mean      29.7
# std       14.5
# min        0.4
# 25%       20.1
# 50%       28.0
# 75%       38.0
# max       80.0
# Name: age, dtype: float64

# %%
titanic['age'].fillna(titanic['age'].median())
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
titanic['age_fixed']= titanic['age'].fillna(titanic['age'].median())

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  age_fixed
# 0    man        True  NaN  Southampton    no  False       22.0
# 1  woman       False    C    Cherbourg   yes  False       38.0
# 2  woman       False  NaN  Southampton   yes   True       26.0
# 3  woman       False    C  Southampton   yes  False       35.0
# 4    man        True  NaN  Southampton    no   True       35.0

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# age_fixed        0
# dtype: int64

# %%
titanic['deck'].mode()
# Out:
# 0    C
# Name: deck, dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
titanic['deck'].value_counts()
# Out:
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# Name: deck, dtype: int64

# %%
properties = pd.read_csv(r"C:\Users\PRASANTH\Downloads\Property_listing.csv")

# %%
properties.head()
# Out:
#   Property_id      Property_type    City    Area  Num_reviews  Avg_rating  \
# 0   PTY006667          Apartment  City02  2780.0        127.0        3.51
# 1   PTY002029  Independent House  City05  1390.0        144.0        3.00
# 2   PTY003101  Independent Rooms  City11   220.0         80.0        2.54
# 3   PTY007902          Apartment  City08  1140.0        189.0        3.05
# 4   PTY002761  Independent Rooms  City05   180.0        180.0        4.60
#
#    Num_rooms  Num_bathrooms  Num_parkingspaces  Floor   Pets_status  \
# 0        2.0              1                2.0      9  Not Accepted
# 1        4.0              3                3.0      2  Not Accepted
# 2        2.0              1                1.0      5    Not Accept
# 3        1.0              3                1.0      9  Not Accepted
# 4        5.0              1                1.0      5  Not Accepted
#
#   Furnished_status  Mthly_rent_amt  Mthly_maint_amt
# 0        Furnished           22080             2550
# ...

# %%
properties.shape
# Out:
# (505, 14)

# %%
properties.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 500     True
# 501     True
# 502     True
# 503     True
# 504     True
# Length: 505, dtype: bool

# %%
properties.duplicated().sum()
# Out:
# 5

# %%
properties[properties.duplicated()]
# Out:
#     Property_id Property_type    City    Area  Num_reviews  Avg_rating  \
# 500   PTY004745     Apartment  City04  2090.0         99.0        4.36
# 501   PTY007902     Apartment  City08  1140.0        189.0        3.05
# 502   PTY002864     Apartment  City02  2620.0        115.0        3.52
# 503   PTY007998     Apartment  City07  1720.0        195.0        4.58
# 504   PTY007844   Guest House  City02  1610.0        159.0        2.84
#
#      Num_rooms  Num_bathrooms  Num_parkingspaces  Floor   Pets_status  \
# 500        2.0              1                2.0     14  Not Accepted
# 501        1.0              3                1.0      9  Not Accepted
# 502        2.0              2                1.0      8  Not Accepted
# 503        3.0              3                2.0     10      Accepted
# 504        NaN              4                3.0      3  Not Accepted
#
#     Furnished_status  Mthly_rent_amt  Mthly_maint_amt
# 500        Furnished           31240             5370
# ...

# %%
properties[properties.duplicated(keep=False)].shape
# Out:
# (10, 14)

# %%
properties[properties.duplicated(keep=False)]
# Out:
#     Property_id Property_type    City    Area  Num_reviews  Avg_rating  \
# 3     PTY007902     Apartment  City08  1140.0        189.0        3.05
# 36    PTY004745     Apartment  City04  2090.0         99.0        4.36
# 99    PTY007844   Guest House  City02  1610.0        159.0        2.84
# 381   PTY007998     Apartment  City07  1720.0        195.0        4.58
# 430   PTY002864     Apartment  City02  2620.0        115.0        3.52
# 500   PTY004745     Apartment  City04  2090.0         99.0        4.36
# 501   PTY007902     Apartment  City08  1140.0        189.0        3.05
# 502   PTY002864     Apartment  City02  2620.0        115.0        3.52
# 503   PTY007998     Apartment  City07  1720.0        195.0        4.58
# 504   PTY007844   Guest House  City02  1610.0        159.0        2.84
#
#      Num_rooms  Num_bathrooms  Num_parkingspaces  Floor   Pets_status  \
# 3          1.0              3                1.0      9  Not Accepted
# ...

# %%
temp = properties[properties.duplicated(keep=False)]
temp.sort_values('Property_id',ascending=False)
# Out:
#     Property_id Property_type    City    Area  Num_reviews  Avg_rating  \
# 381   PTY007998     Apartment  City07  1720.0        195.0        4.58
# 503   PTY007998     Apartment  City07  1720.0        195.0        4.58
# 3     PTY007902     Apartment  City08  1140.0        189.0        3.05
# 501   PTY007902     Apartment  City08  1140.0        189.0        3.05
# 99    PTY007844   Guest House  City02  1610.0        159.0        2.84
# 504   PTY007844   Guest House  City02  1610.0        159.0        2.84
# 36    PTY004745     Apartment  City04  2090.0         99.0        4.36
# 500   PTY004745     Apartment  City04  2090.0         99.0        4.36
# 430   PTY002864     Apartment  City02  2620.0        115.0        3.52
# 502   PTY002864     Apartment  City02  2620.0        115.0        3.52
#
#      Num_rooms  Num_bathrooms  Num_parkingspaces  Floor   Pets_status  \
# 381        3.0              3                2.0     10      Accepted
# ...

# %%
properties.drop_duplicates().shape
# Out:
# (500, 14)

# %%
properties.drop_duplicates(inplace=True)

# %%
properties.shape
# Out:
# (500, 14)

# %%
df = pd.read_csv('bank_data.csv',sep=';')

# %%
df.head(3)
# Out:
#    age         job  marital  education default  balance housing loan  \
# 0   30  unemployed  married    primary      no     1787      no   no
# 1   33    services  married  secondary      no     4789     yes  yes
# 2   35  management   single   tertiary      no     1350     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no

# %%
sns.set_theme()

# %%
sns.boxplot(df['age'])
# Out:
# C:\Users\PRASANTH\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %%
df['age'].describe().round(1)
# Out:
# count    4521.0
# mean       41.2
# std        10.6
# min        19.0
# 25%        33.0
# 50%        39.0
# 75%        49.0
# max        87.0
# Name: age, dtype: float64

# %%
plt.figure(figsize=(15,4))
sns.boxplot(data=df,x='age');

# %%
df['balance'].describe([0.01,0.05,0.1,0.9,0.95,0.99]).round(1)
# Out:
# count     4521.0
# mean      1422.7
# std       3009.6
# min      -3313.0
# 1%        -671.4
# 5%        -162.0
# 10%          0.0
# 50%        444.0
# 90%       3913.0
# 95%       6102.0
# 99%      14194.6
# max      71188.0
# Name: balance, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df,x='balance')
# Out:
# <AxesSubplot:xlabel='balance'>

# %%
a = np.random.randint(-20,100,10)
a
# Out:
# array([-16,  59,   3,  67,  52,  -4, -11,  27,  95,   5])

# %%
a<0
# Out:
# array([ True, False, False, False, False,  True,  True, False, False,
#        False])

# %%
np.where(a<0,0,a)
# Out:
# array([ 0, 59,  3, 67, 52,  0,  0, 27, 95,  5])

# %%
b = np.random.randint(-20,100,size=(10,5))

# %%
b
# Out:
# array([[ 42, -20,  22,  49,   4],
#        [ 45,  66,  23,   9,  42],
#        [ 40,  72,   2,  68,  57],
#        [-16,  -6,  31,   8,  -1],
#        [ 77,  72,  21,  14,  42],
#        [  2,  65,  28,  94,  81],
#        [ 48,  61,   0,  95, -16],
#        [ 92,  42,  29,  12,  89],
#        [ 96, -15,  -9,  63,  85],
#        [-19,   2,  85,  -3,  49]])

# %%
temp =pd.DataFrame(b,columns=['v1','v2','v3','v4','v5'])
temp
# Out:
#    v1  v2  v3  v4  v5
# 0  42 -20  22  49   4
# 1  45  66  23   9  42
# 2  40  72   2  68  57
# 3 -16  -6  31   8  -1
# 4  77  72  21  14  42
# 5   2  65  28  94  81
# 6  48  61   0  95 -16
# 7  92  42  29  12  89
# 8  96 -15  -9  63  85
# 9 -19   2  85  -3  49

# %%
np.where(temp['v5']<0,1,temp['v5'])
# Out:
# array([ 4, 42, 57,  1, 42, 81,  1, 89, 85, 49])

# %%
temp['vs_floored'] = np.where(temp['v5']<0,0,temp['v5'])
temp
# Out:
#    v1  v2  v3  v4  v5  vs_floored
# 0  42 -20  22  49   4           4
# 1  45  66  23   9  42          42
# 2  40  72   2  68  57          57
# 3 -16  -6  31   8  -1           0
# 4  77  72  21  14  42          42
# 5   2  65  28  94  81          81
# 6  48  61   0  95 -16           0
# 7  92  42  29  12  89          89
# 8  96 -15  -9  63  85          85
# 9 -19   2  85  -3  49          49

# %%
temp['v5_capped']= np.where(temp['v5']>70,70,temp['v5'])
temp
# Out:
#    v1  v2  v3  v4  v5  vs_floored  v5_capped
# 0  42 -20  22  49   4           4          4
# 1  45  66  23   9  42          42         42
# 2  40  72   2  68  57          57         57
# 3 -16  -6  31   8  -1           0         -1
# 4  77  72  21  14  42          42         42
# 5   2  65  28  94  81          81         70
# 6  48  61   0  95 -16           0        -16
# 7  92  42  29  12  89          89         70
# 8  96 -15  -9  63  85          85         70
# 9 -19   2  85  -3  49          49         49
