# %% [markdown]
# # Reading input files of different formats

# %% [markdown]
# ### Setting the Working Directory

# %%
import os
os.chdir('D:\Work\B2B\Aditya Group\Module 02 Lectures\Lecture 01')
os.getcwd()
# Out:
# 'D:\\Work\\B2B\\Aditya Group\\Module 02 Lectures\\Lecture 01'

# %%
os.listdir()
# Out:
# ['csv_datafile.csv',
#  'Sales Data.xlsx',
#  'text_data_comma.txt',
#  'text_data_tab.txt']

# %%
import pandas as pd

# %% [markdown]
# ### CSV file

# %%
pd.read_csv('csv_datafile.csv')
# Out:
#       Student Name  Class Section  Rollno  English  Mathemetics  Science
# 0     Neel Pittman      8       A       1       38           58       30
# 1   Marnie Mohamed      8       A       2       53           47       46
# 2     Tala Vasquez      8       A       3       57           38       59
# 3      Fraya Ellis      8       A       4       59           53       35
# 4   Clarissa Cowan      8       A       5       47           36       54
# 5  Cherish Camacho      8       A       6       31           47       35
# 6    Rosalie Short      8       A       7       48           49       52
# 7       Taiba Carr      8       A       8       49           52       37
# 8         Bob Roth      8       A       9       52           35       44
# 9    Penny Sampson      8       A      10       46           37       60

# %% [markdown]
# ### Text file with comma delimiter

# %%
pd.read_csv('text_data_comma.txt')
# Out:
#     Class Section  Rollno     Student Name  Sem1_English  Sem1_Mathemetics  \
# 0       8       A       1     Neel Pittman            38                58
# 1       8       A       2   Marnie Mohamed            53                47
# 2       8       A       3     Tala Vasquez            57                38
# 3       8       A       4      Fraya Ellis            59                53
# 4       8       A       5   Clarissa Cowan            47                36
# 5       8       A       6  Cherish Camacho            31                47
# 6       8       A       7    Rosalie Short            48                49
# 7       8       A       8       Taiba Carr            49                52
# 8       8       A       9         Bob Roth            52                35
# 9       8       A      10    Penny Sampson            46                37
# 10      8       B       1  Mikaeel Estrada            35                47
# ...

# %% [markdown]
# ### Text file with TAB delimiter

# %%
pd.read_csv('text_data_tab.txt')
# Out:
#    Class\tSection\tRollno\tStudent Name\tSem1_English\tSem1_Mathemetics\tSem1_Science\tSem2_English\tSem2_Mathemetics\tSem2_Science
# 0       8\tA\t1\tNeel Pittman\t38\t58\t30\t34\t55\t39
# 1     8\tA\t2\tMarnie Mohamed\t53\t47\t46\t52\t43\t42
# 2       8\tA\t3\tTala Vasquez\t57\t38\t59\t60\t41\t32
# 3        8\tA\t4\tFraya Ellis\t59\t53\t35\t39\t46\t44
# 4     8\tA\t5\tClarissa Cowan\t47\t36\t54\t40\t37\t54
# 5    8\tA\t6\tCherish Camacho\t31\t47\t35\t49\t52\t55
# 6      8\tA\t7\tRosalie Short\t48\t49\t52\t51\t40\t40
# 7         8\tA\t8\tTaiba Carr\t49\t52\t37\t30\t41\t34
# 8           8\tA\t9\tBob Roth\t52\t35\t44\t50\t48\t47
# 9     8\tA\t10\tPenny Sampson\t46\t37\t60\t30\t32\t46
# 10   8\tB\t1\tMikaeel Estrada\t35\t47\t57\t35\t44\t55
# 11     8\tB\t2\tBertha Obrien\t52\t45\t51\t46\t30\t50
# 12     8\tB\t3\tLeyton Curtis\t31\t52\t41\t45\t52\t31
# 13       8\tB\t4\tAlton Hicks\t43\t41\t33\t41\t36\t30
# 14    8\tB\t5\tMylee Delacruz\t30\t41\t54\t39\t35\t52
# ...

# %%
pd.read_csv('text_data_tab.txt',sep='\t')
# Out:
#     Class Section  Rollno     Student Name  Sem1_English  Sem1_Mathemetics  \
# 0       8       A       1     Neel Pittman            38                58
# 1       8       A       2   Marnie Mohamed            53                47
# 2       8       A       3     Tala Vasquez            57                38
# 3       8       A       4      Fraya Ellis            59                53
# 4       8       A       5   Clarissa Cowan            47                36
# 5       8       A       6  Cherish Camacho            31                47
# 6       8       A       7    Rosalie Short            48                49
# 7       8       A       8       Taiba Carr            49                52
# 8       8       A       9         Bob Roth            52                35
# 9       8       A      10    Penny Sampson            46                37
# 10      8       B       1  Mikaeel Estrada            35                47
# ...

# %% [markdown]
# ### Excel file with Multiple Tabs/ Sheets

# %%
pd.read_excel('Sales Data.xlsx')
# Out:
#    Unnamed: 0   Unnamed: 1                                         Unnamed: 2
# 0         NaN     Variable                                        Description
# 1         NaN       Region                     Region in which the store lies
# 2         NaN         City                       Coty in which the store lies
# 3         NaN      Product                                    Product of sale
# 4         NaN        Month                                      Month of sale
# 5         NaN    Unitssold                Number of Units sold of the product
# 6         NaN     Totalrev  Total actual revenue generated in a month from...
# 7         NaN  Totaltarget  Total sales revenue Target set for a product f...
# 8         NaN      Numcust  Number of customers who bought that product in...

# %% [markdown]
# ### Specifying sheet_name to be read from Excel file

# %%
pd.read_excel('Sales Data.xlsx',sheet_name='Store Sales')
# Out:
#        Region    City       Product Year_Month  Unitssold  Totalrev  \
# 0   Northeast  City19    Smartphone 2018-08-01        144    406009
# 1   Northeast  City31    Smartphone 2018-10-01        107    833800
# 2     Central   City8     PowerBank 2016-06-01         17    680229
# 3       South  City23     eNotebook 2010-01-01        105    348521
# 4   Southeast  City11     Amplifier 2014-12-01        130    771793
# 5   Northwest   City8       eReader 2019-09-01         40    765612
# 6   Southwest   City7  Music Player 2013-04-01         77    985956
# 7   Southwest   City8     eNotebook 2010-07-01         39    759619
# 8        West  City23     PowerBank 2018-02-01         58    532929
# 9       South  City13       eReader 2018-09-01        150    530818
# 10  Northwest   City4  Music Player 2010-05-01         91    272051
# 11      South   City8    Smartphone 2012-06-01         31    370663
# 12  Northwest  City27      Smart TV 2013-05-01         30    224145
# ...
